# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
from plotly import __version__

# %%
print(__version__)
# Out:
# 5.9.0

# %%
import cufflinks as cf

# %%
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# Data

df = pd.DataFrame(np.random.randn(100,4),columns='A B C D'.split())

# %%
df
# Out:
#            A         B         C         D
# 0  -0.609473 -1.024130  0.547490  1.298722
# 1  -1.011323  1.096211  1.836729  1.035755
# 2   1.087691  0.118973  2.643125 -0.867854
# 3  -0.004100 -0.305047  1.699940  1.630674
# 4   2.152833  0.331688  0.557575 -0.743328
# ..       ...       ...       ...       ...
# 95 -0.496390  0.072290 -1.237101  0.436715
# 96  1.238103  1.035431  0.901246 -0.732489
# 97  1.406283  0.961992  0.453542  1.627443
# 98 -0.277502  0.949227  0.158746  0.131997
# 99 -0.927571  0.816045 -0.142963  1.060419
#
# [100 rows x 4 columns]

# %%
df2 = pd.DataFrame({'Category':['A','B','C'],'Values':[32,43,50]})

# %%
df2
# Out:
#   Category  Values
# 0        A      32
# 1        B      43
# 2        C      50

# %%
# interactive line plot

df.iplot()
# Out:
# <div>                            <div id="d74b5689-00bd-4353-91de-f29171ca4938" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
# Create other plots

# %%
# Scatter Plots

df.iplot(kind='scatter',x='A',y='B',mode='markers',size=12)
# Out:
# <div>                            <div id="fc7d5000-afb0-4604-a887-9009f0e28d34" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
# Bar Chart

df2.iplot(kind='bar',x='Category',y='Values')
# Out:
# <div>                            <div id="a8e32d66-e850-4fdd-81a2-7541d0e9388b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
# Aggregate/group by to get bar chart compatible values

# Count
# df.count().iplot(kind='bar')

#Sum
df.sum().iplot(kind='bar')
# Out:
# <div>                            <div id="ce33d4f8-bd5d-4920-a0e6-a9df616bfcc0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
# Box Plots

df.iplot(kind='box')
# Out:
# <div>                            <div id="9d6f2741-714e-4eb8-ad8b-f9f753e75a65" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
# 3D Surface Plot

# %%
df3 = pd.DataFrame({'x':[1,2,3,4,5],'y':[10,20,30,20,10],'z':[500,400,300,200,100]})

# %%
df3
# Out:
#    x   y    z
# 0  1  10  500
# 1  2  20  400
# 2  3  30  300
# 3  4  20  200
# 4  5  10  100

# %%
df3.iplot(kind='surface')
# Out:
# <div>                            <div id="3a14624f-f608-461f-8d9e-f0d5f123ea4d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df3 = pd.DataFrame({'x':[1,2,3,4,5],'y':[10,20,30,20,10],'z':[5,4,3,2,1]})

df3.iplot('surface',colorscale='rdylbu')
# Out:
# <div>                            <div id="59ca89f9-5d52-418f-9f41-5ddfc19d505c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
# Histogram

df['A'].iplot(kind='hist',bins=50)
# Out:
# <div>                            <div id="7917b27f-c792-4a63-8d1a-e1b4bfa8e046" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='hist',bins=50)
# Out:
# <div>                            <div id="9ca1d2e0-529f-4f2a-bbdd-8ae87e23e815" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
# Spread

# %%
df[['A','B']].iplot(kind='spread')
# Out:
# C:\Users\m2sta\anaconda3\lib\site-packages\cufflinks\plotlytools.py:849: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
#
# C:\Users\m2sta\anaconda3\lib\site-packages\cufflinks\plotlytools.py:850: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
# <div>                            <div id="5e24df4c-f072-4f3e-abc4-27b510271091" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
# Bubble Plot

df.iplot(kind='bubble',x='A',y='B',size='C')
# Out:
# <div>                            <div id="676b022d-e4b9-4e72-bb5b-5fce61d27983" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
# Scatter Matrix
# be careful using this with large datasets

df.scatter_matrix()
# Out:
# <div>                            <div id="4e945ee0-fba2-4cd4-9d7b-7b68417f154a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
